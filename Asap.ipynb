# %% [markdown]
# <a href="https://colab.research.google.com/github/Aasthapaudel/datathon/blob/main/Asap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv("/content/set1.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   District      80 non-null     object
#  1   Male          80 non-null     int64
#  2   Female        80 non-null     int64
#  3   Third Gender  80 non-null     int64
#  4   Total         80 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 3.2+ KB

# %%
df.head()
# Out:
#        District   Male  Female  Third Gender   Total
# 0        Achham  60441   67299             2  127742
# 1  Arghakhanchi  60296   66403             0  126699
# 2       Baglung  73963   82839             0  156802
# 3       Baitadi  60227   64596             1  124824
# 4       Bajhang  47888   49721             1   97610

# %%
df.tail()
# Out:
#      District     Male   Female  Third Gender     Total
# 75     Tanahu    90144  3104327             0    194471
# 76  Taplejung    37187    33591             0     70778
# 77  Terhathum    30334    30370             0     60704
# 78   Udayapur    88510    86951             0    175461
# 79      Total  7069714  6984625           143  14054482

# %%
df.describe()
# Out:
#                Male        Female  Third Gender
# count  8.000000e+01  8.000000e+01     80.000000
# mean   1.851372e+05  2.546872e+05      3.562500
# std    7.849834e+05  8.991922e+05     16.160464
# min    0.000000e+00  0.000000e+00      0.000000
# 25%    4.577675e+04  4.948575e+04      0.000000
# 50%    7.526500e+04  8.288850e+04      1.000000
# 75%    1.252198e+05  1.286485e+05      2.000000
# max    7.069714e+06  6.984625e+06    143.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   District      80 non-null     object
#  1   Male          80 non-null     int64
#  2   Female        80 non-null     int64
#  3   Third Gender  80 non-null     int64
#  4   Total         80 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 3.2+ KB

# %%
df.replace('???? ,np.nan')
# Out:
#         District     Male   Female  Third Gender     Total
# 0         Achham    60441    67299             2    127742
# 1   Arghakhanchi    60296    66403             0    126699
# 2        Baglung    73963    82839             0    156802
# 3        Baitadi    60227    64596             1    124824
# 4        Bajhang    47888    49721             1     97610
# ..           ...      ...      ...           ...       ...
# 75        Tanahu    90144  3104327             0    194471
# 76     Taplejung    37187    33591             0     70778
# 77     Terhathum    30334    30370             0     60704
# 78      Udayapur    88510    86951             0    175461
# 79         Total  7069714  6984625           143  14054482
#
# [80 rows x 5 columns]

# %%
df1=df.drop_duplicates(keep='first')

# %%
df1
# Out:
#         District     Male   Female  Third Gender     Total
# 0         Achham    60441    67299             2    127742
# 1   Arghakhanchi    60296    66403             0    126699
# 2        Baglung    73963    82839             0    156802
# 3        Baitadi    60227    64596             1    124824
# 4        Bajhang    47888    49721             1     97610
# ..           ...      ...      ...           ...       ...
# 74       Syangja    89544   101708             1    191253
# 76     Taplejung    37187    33591             0     70778
# 77     Terhathum    30334    30370             0     60704
# 78      Udayapur    88510    86951             0    175461
# 79         Total  7069714  6984625           143  14054482
#
# [77 rows x 5 columns]

# %%
df1['Total'].loc[27]=(df1['Male'].loc[27] +df1['Female'].loc[27])
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77 entries, 0 to 79
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   District      77 non-null     object
#  1   Male          77 non-null     int64
#  2   Female        77 non-null     int64
#  3   Third Gender  77 non-null     int64
#  4   Total         77 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 5.7+ KB

# %%
df1.isnull()
# Out:
#     District   Male  Female  Third Gender  Total
# 0      False  False   False         False  False
# 1      False  False   False         False  False
# 2      False  False   False         False  False
# 3      False  False   False         False  False
# 4      False  False   False         False  False
# ..       ...    ...     ...           ...    ...
# 74     False  False   False         False  False
# 76     False  False   False         False  False
# 77     False  False   False         False  False
# 78     False  False   False         False  False
# 79     False  False   False         False  False
#
# [77 rows x 5 columns]

# %%
df1.isnull().sum()
# Out:
# District        0
# Male            0
# Female          0
# Third Gender    0
# Total           0
# dtype: int64

# %%
df1.sort_values(by=['Total'],ascending=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-ec76c841f66c> in <module>
# ----> 1 df1.sort_values(by=['Total'],ascending=True)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6268                 ascending = ascending[0]
#    6269
# -> 6270             indexer = nargsort(
#    6271                 k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    6272             )
#
# ...

# %%
df1['Female'].loc[49]=df1['Total'].loc[49].sub(df1['Male'].loc[49])
